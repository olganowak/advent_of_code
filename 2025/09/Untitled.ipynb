# %%
from itertools import combinations

example = """7,1
11,1
11,7
9,7
9,5
2,5
2,3
7,3"""

tiles = [tuple(int(x) for x in line.split(",")) for line in example.split()]

tiles
# Out:
# [(7, 1), (11, 1), (11, 7), (9, 7), (9, 5), (2, 5), (2, 3), (7, 3)]

# %%
with open("input.txt") as f:
    tiles = [tuple(int(x) for x in line.split(",")) for line in f.read().split()]

# %%
tile_combinations = list(combinations(tiles, 2))
tile_combinations
# Out:
# [((7, 1), (11, 1)),
#  ((7, 1), (11, 7)),
#  ((7, 1), (9, 7)),
#  ((7, 1), (9, 5)),
#  ((7, 1), (2, 5)),
#  ((7, 1), (2, 3)),
#  ((7, 1), (7, 3)),
#  ((11, 1), (11, 7)),
#  ((11, 1), (9, 7)),
#  ((11, 1), (9, 5)),
#  ((11, 1), (2, 5)),
#  ((11, 1), (2, 3)),
#  ((11, 1), (7, 3)),
#  ((11, 7), (9, 7)),
#  ((11, 7), (9, 5)),
#  ((11, 7), (2, 5)),
#  ((11, 7), (2, 3)),
#  ((11, 7), (7, 3)),
#  ((9, 7), (9, 5)),
#  ((9, 7), (2, 5)),
#  ((9, 7), (2, 3)),
#  ((9, 7), (7, 3)),
#  ((9, 5), (2, 5)),
#  ((9, 5), (2, 3)),
#  ((9, 5), (7, 3)),
#  ((2, 5), (2, 3)),
#  ((2, 5), (7, 3)),
#  ((2, 3), (7, 3))]

# %%
maximum = 0 
for t1, t2 in tile_combinations:
    x1, y1 = t1
    x2, y2 = t2
    area = (abs(x2 - x1) + 1) * (abs(y2 - y1) + 1)
    if area > maximum:
        maximum = area
maximum
# Out:
# 50

# %%
min_rows = min([tile[1] for tile in tiles])
min_rows
# Out:
# 1529

# %%
max_rows = max([tile[1] for tile in tiles])
rows
# Out:
# 98329

# %%
cols = max([x[0] for x in tiles])
cols
# Out:
# 98364

# %%
floor = [list("." * (cols + 3)) for row in range(rows + 2)]
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x11042e090>>
# Traceback (most recent call last):
#   File "/Users/olganowak/.pyenv/versions/3.12.9/envs/lewagon/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:

# %%
for x, y in tiles:
    floor[y][x] = "#"
    
##for row in floor:
    print("".join(row))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 for x, y in tiles:
# ----> 2     floor[y][x] = "#"
#       4 ##for row in floor:
#       5     print("".join(row))
#
# IndexError: list index out of range
